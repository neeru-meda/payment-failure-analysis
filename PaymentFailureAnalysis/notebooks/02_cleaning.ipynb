# %% [markdown]
# Checking for the duplicates

# %%
import pandas as pd
df = pd.read_csv('../data/transactions_raw.csv')
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Check failure_reasons column, if there are any null values. If present fill with unknown.

# %%
df.failure_reason.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# telling that timestamp is data and time

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %% [markdown]
# create binary columns (is_failed,status)

# %%
df['is_failed'] = (df['status']=='Failed').astype(int)

# %% [markdown]
# save cleaned data as new csv file

# %%
df.to_csv('../data/transactions_cleaned.csv',index=False)
